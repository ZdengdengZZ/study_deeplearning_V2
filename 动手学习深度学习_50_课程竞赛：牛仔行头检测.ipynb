# %% [markdown]
# # 牛仔行头检测
#
# ![image.png](attachment:image.png)
#
# https://www.kaggle.com/c/cowboyoutfits/

# %% [markdown]
# ![image.png](attachment:image.png)
#
# 如果用随机采样 看到腰带的概率低
# 如果看到腰带可以做特殊处理
