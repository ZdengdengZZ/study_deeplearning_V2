# %% [markdown]
# # 束搜索
# ![image.png](attachment:image.png)

# %% [markdown]
# # 贪心算法(S2S中)
#
# # 贪心是最快的 但不是最好的
#
#
# # 将预测得到的最大概率输出
#
# 但贪心也不是最优的
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # 最优的情况 遍历所有的序列
#
# # 穷举搜索
#
# # 是最好的但是不可计算的
#
# ![image.png](attachment:image.png)
#
# # 但是这种情况计算上时间太长了 不可行

# %% [markdown]
# # 上述两种算法取中间的东西就是
#
# # 束搜索
#
# ![image.png](attachment:image.png)
#
# 第一轮假设k=2 选两个当前最好的情况
#
# 在第二轮 对n个候选在选择一项最好的
#
# 整体上在kn个选项中选择最好的k个
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)
#
# # 写错了
#
# K=N不是穷举。K=N是始终只记录N个最优的，穷举是指数级的
